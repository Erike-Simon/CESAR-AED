# %% [markdown]
# <a href="https://colab.research.google.com/github/Erike-Simon/CESAR-AED/blob/main/RNA_YOLO_V8_ANIMALS_CLASSIFICATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto Final - RNA e Deep Learning
#
# **Alunos:** Erike Simon e José Aparecido
#
# O objetivo desse projeto final é a aplicação dos conhecimentos adquiridos durante o curso para desenvolver um modelo customizado que realize a classificação de imagens ou a detecção de objetos em imagens.
#
# Para esse projeto é necessário o uso de um dataset (conjunto de dados) criado pelo aluno. Esse dataset já foi criado em uma atividade anterior. Recomenda-se a utilização da ferramenta Roboflow para a criação e marcação do dataset.
#
#
# Para o desenvolvimento do projeto, você deve:
# *   Escolher se quer fazer uma classificação de imagens ou detecção de objetos
# em imagens.
# *   A partir dessa decisão, você deve escolher um modelo apropriado (durante as aulas eu apresentei YOLOv5 e MobileNetv2, mas você é livre e incentivado a usar outro modelo).
# *   A partir da escolha do modelo, você deve então criar um Jupyter Notebook para realizar o treinamento. Esse notebook deve ser salvo e submetido nessa atividade (falarei mais sobre isso abaixo).
# *   Feito o treinamento, vocês precisam submeter as métricas de treinamento (pelo menos Acurácia/Precisão). Se usar Weights&Bias (https://wandb.ai/), anexar os dados de lá, caso contrário, colocar prints de análise manual.
#
# (Bônus)
# *   Como atividade Bônus, você deve publicar o projeto no HuggingFace (huggingface.co), estando esse modelo disponível para ser testado.
#
#
# **Submissão do Projeto**
#
# Para entrega desse projeto, você deve criar um repositório no GitHub (github.com). Esse repositório deve conter:
#
# *   Uma pasta chamada "dataset" contendo as imagens utilizadas no treinamento
# *   Uma pasta chamada "models" contendo o snapshot do modelo (seja o modelo exportado, seja os pesos da melhor época)
# *   Um arquivo Jupyter Notebook contendo todo o código de treinamento e mantendo as saídas (outputs) dos blocos
# *   Uma pasta chamada "assets" que deve conter quaisquer outras imagens ou arquivos necessários
# *  Um arquivo "README.md". Esse arquivo deve conter diversas informações sobre o projeto. Anexo a essa atividade está disponível um modelo a ser preenchido.
# *  A entrega do projeto deve conter somente o link do repositório do GitHub!
#
# **Cálculo da Nota**
#
# O cálculo da nota desse projeto é feito a partir da soma dos seguintes critérios (com limite 10):
# *   3 pontos: Jupyter Notebook (com uma tentativa de treinamento)
# *   5 pontos: Modelo treinado com ao menos 50% de acurácia/precisão
# *   2 pontos: Modelo treinado com 80% ou mais de acurácia/precisão
# *   2 pontos: Modelo publicado no HuggingFace
#
# Você deve perceber que a somatória dos pontos atinge 12 pontos, isso é proposital: dessa forma, você pode falhar em algum critério e compensar com outro. Perceba que a atividade bônus de publicação do projeto no HugginFace pode lhe dar 2 pontos!
#
# Assim, a nota máxima será a somatória dos pontos, com limite 10.
#
# **Deadline**
#
# O período para a conclusão desse projeto é de 1 semana a partir da finalização das aulas.
#
# Dúvidas: vc@cesar.school ou vc@cesar.org.br
#
# Link para atividade no Classroom: https://classroom.google.com/c/NjAxNDI1OTYwNTA0/a/NTkwMjExOTYyMzAw/details

# %% [markdown]
# # Configurações iniciais

# %% [markdown]
# ## Baixando as dependências

# %% [markdown]
# ### Configurando acesso ao Google Drive

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls '/content/gdrive/My Drive/Colab Notebooks/CESAR/rna-deep-learning/Projeto-Classificação'

# %% [markdown]
# ### Configurando ambiente

# %%
# Verifica se está executando no ambiente correto. Deve executar utilizando GPU

# !nvidia-smi
# Out:
# Thu Oct 19 18:52:19 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Define variável  HOME

# %%
import os

HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ### Configurando o RoboFlow e faz download do dataset

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="E0rlyzmoGDea1UyBaAUf")
project = rf.workspace("cesar-school-recife").project("new-animals-classification")
dataset = project.version(1).download("folder")
# Out:
# /content/datasets
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 24.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in New-Animals-Classification-1 to folder:: 100%|██████████| 35254/35254 [00:01<00:00, 19767.65it/s]
# Extracting Dataset Version Zip to New-Animals-Classification-1 in folder:: 100%|██████████| 536/536 [00:00<00:00, 4542.45it/s]

# %%
dataset.location
# Out:
# '/content/datasets/New-Animals-Classification-1'

# %% [markdown]
# Verifica os arquivos baixados

# %%
# %cd New-Animals-Classification-1/train/rhinoceros

# %ls | wc -l
# Out:
# /content/datasets/New-Animals-Classification-1/train/rhinoceros
# 167

# %% [markdown]
# ### Configurando o Wandb

# %%
# !pip install wandb -qU

# Log in to your W&B account
import wandb

wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
config = {
    "project": "cesar-scholl-animals-classification-yolov8", # TODO CRIAR UMA CONSTANTE
    "num_of_classes": 3
}
run = wandb.init(project = config["project"], config = config)


artifact = wandb.Artifact(
    name = "yolov8-data",
    type = "dataset"
)

artifact.add_dir(dataset.location)
wandb.log_artifact(artifact)
# Out:
# wandb: Currently logged in as: erike-fisica (cesar-recife). Use `wandb login --relogin` to force relogin
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112790944444366, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/datasets/New-Animals-Classification-1/train/rhinoceros/wandb/run-20231019_185404-zu4b49ux</code>
# Syncing run <strong><a href='https://wandb.ai/cesar-recife/cesar-scholl-animals-classification-yolov8/runs/zu4b49ux' target="_blank">polar-pond-2</a></strong> to <a href='https://wandb.ai/cesar-recife/cesar-scholl-animals-classification-yolov8' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/cesar-recife/cesar-scholl-animals-classification-yolov8' target="_blank">https://wandb.ai/cesar-recife/cesar-scholl-animals-classification-yolov8</a>
#  View run at <a href='https://wandb.ai/cesar-recife/cesar-scholl-animals-classification-yolov8/runs/zu4b49ux' target="_blank">https://wandb.ai/cesar-recife/cesar-scholl-animals-classification-yolov8/runs/zu4b49ux</a>
# wandb: Adding directory to artifact (/content/datasets/New-Animals-Classification-1)... Done. 0.4s
# <Artifact yolov8-data>

# %%
pip install --upgrade ultralytics==8.0.186 wandb

# %% [markdown]
# ### Configurando rede de detecção de objetos YOLO

# %%
# !pip install ultralytics --quiet

from IPython import display
display.clear_output()

from ultralytics import YOLO

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.186 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.4/78.2 GB disk)

# %%
from IPython.display import display, Image

# %% [markdown]
# Verifica se a rede YOLO está configurada corretamente

# %%
# %cd {HOME}
# !yolo task=classify mode=predict model=yolov8n-cls.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg'
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n-cls.pt to 'yolov8n-cls.pt'...
# 100% 5.28M/5.28M [00:00<00:00, 67.8MB/s]
# Ultralytics YOLOv8.0.186 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients
#
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to 'dog.jpeg'...
# 100% 104k/104k [00:00<00:00, 109MB/s]
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 20.2MB/s]
# image 1/1 /content/dog.jpeg: 224x224 basset 0.46, beagle 0.27, Walker_hound 0.20, English_foxhound 0.02, bloodhound 0.01, 3.7ms
# Speed: 31.6ms preprocess, 3.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/classify/predict/dog.jpeg', height=600)
# Out:
# /content

# %% [markdown]
# # Executando treinamento com o YOLO

# %% [markdown]
# ## Executando treinamento com Python e apenas uma época

# %%
# %cd {HOME}

# Load a model
model = YOLO("yolov8n-cls.pt")  # load a pretained model

# Use the model
results = model.train(data=dataset.location, epochs=1, imgsz=64)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.0.200 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.186 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=classify, mode=train, model=yolov8n-cls.pt, data=/content/datasets/New-Animals-Classification-1, epochs=1, patience=50, batch=16, imgsz=64, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/classify/train
# train: /content/datasets/New-Animals-Classification-1/train... found 455 images in 3 classes ✅
# val: None...
# test: /content/datasets/New-Animals-Classification-1/test... found 22 images in 3 classes ✅
# /content
# Overriding model.yaml nc=1000 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    334083  ultralytics.nn.modules.head.Classify         [256, 3]
# YOLOv8n-cls summary: 99 layers, 1442131 parameters, 1442131 gradients
# Transferred 156/158 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/classify/train', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 117MB/s]
# AMP: checks passed ✅
# train: Scanning /content/datasets/New-Animals-Classification-1/train... 455 images, 0 corrupt: 100%|██████████| 455/455 [00:00<00:00, 5154.96it/s]
# train: New cache created: /content/datasets/New-Animals-Classification-1/train.cache
# albumentations: RandomResizedCrop(p=1.0, height=64, width=64, scale=(0.5, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1), HorizontalFlip(p=0.5), ColorJitter(p=0.5, brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.30000000000000004, 1.7], hue=[-0.015, 0.015]), Normalize(p=1.0, mean=(0.0, 0.0, 0.0), std=(1.0, 1.0, 1.0), max_pixel_value=255.0), ToTensorV2(always_apply=True, p=1.0, transpose_mask=False)
# val: Scanning /content/datasets/New-Animals-Classification-1/test... 22 images, 0 corrupt: 100%|██████████| 22/22 [00:00<00:00, 14165.60it/s]
# val: New cache created: /content/datasets/New-Animals-Classification-1/test.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 64 train, 64 val
# Using 2 dataloader workers
# Logging results to runs/classify/train
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#         1/1      0.39G     0.2833          7         64: 100%|██████████| 29/29 [00:03<00:00,  7.25it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,  6.68it/s]
#                    all      0.455          1
#
# 1 epochs completed in 0.003 hours.
# Optimizer stripped from runs/classify/train/weights/last.pt, 3.0MB
# Optimizer stripped from runs/classify/train/weights/best.pt, 3.0MB
#
# Validating runs/classify/train/weights/best.pt...
# Ultralytics YOLOv8.0.186 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1438723 parameters, 0 gradients
# WARNING ⚠️ Dataset 'split=val' not found, using 'split=test' instead.
# train: /content/datasets/New-Animals-Classification-1/train... found 462 images in 4 classes: ERROR ❌️ requires 3 classes, not 4
# val: None...
# test: /content/datasets/New-Animals-Classification-1/test... found 22 images in 3 classes ✅
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 55.97it/s]
#                    all      0.455          1
# Speed: 0.0ms preprocess, 0.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train
# Results saved to runs/classify/train

# %% [markdown]
# ## Executando treinamento de modelo com CLI e 1 época

# %%
# %cd {HOME}

# !yolo task=classify mode=train model=yolov8n-cls.pt data={dataset.location} epochs=1
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.0.200 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.186 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=classify, mode=train, model=yolov8n-cls.pt, data=/content/datasets/New-Animals-Classification-1, epochs=1, patience=50, batch=16, imgsz=224, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/classify/train2
# train: /content/datasets/New-Animals-Classification-1/train... found 465 images in 4 classes: ERROR ❌️ requires 3 classes, not 4
# val: None...
# test: /content/datasets/New-Animals-Classification-1/test... found 22 images in 3 classes ✅
# Overriding model.yaml nc=1000 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    334083  ultralytics.nn.modules.head.Classify         [256, 3]
# YOLOv8n-cls summary: 99 layers, 1442131 parameters, 1442131 gradients
# Transferred 156/158 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/classify/train2', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/datasets/New-Animals-Classification-1/train... 475 images, 0 corrupt: 100% 475/475 [00:00<00:00, 4683.23it/s]
# train: New cache created: /content/datasets/New-Animals-Classification-1/train.cache
# albumentations: RandomResizedCrop(p=1.0, height=224, width=224, scale=(0.5, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1), HorizontalFlip(p=0.5), ColorJitter(p=0.5, brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.30000000000000004, 1.7], hue=[-0.015, 0.015]), Normalize(p=1.0, mean=(0.0, 0.0, 0.0), std=(1.0, 1.0, 1.0), max_pixel_value=255.0), ToTensorV2(always_apply=True, p=1.0, transpose_mask=False)
# val: Scanning /content/datasets/New-Animals-Classification-1/test... 22 images, 0 corrupt: 100% 22/22 [00:00<?, ?it/s]
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 2 dataloader workers
# Logging results to runs/classify/train2
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#         1/1     0.394G     0.2604         11        224: 100% 30/30 [00:04<00:00,  7.23it/s]
#                classes   top1_acc   top5_acc: 100% 1/1 [00:00<00:00,  6.00it/s]
#                    all      0.545          1
#
# 1 epochs completed in 0.002 hours.
# Optimizer stripped from runs/classify/train2/weights/last.pt, 3.0MB
# Optimizer stripped from runs/classify/train2/weights/best.pt, 3.0MB
#
# Validating runs/classify/train2/weights/best.pt...
# Ultralytics YOLOv8.0.186 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1438723 parameters, 0 gradients
# WARNING ⚠️ Dataset 'split=val' not found, using 'split=test' instead.
# train: /content/datasets/New-Animals-Classification-1/train... found 465 images in 4 classes: ERROR ❌️ requires 3 classes, not 4
# val: None...
# test: /content/datasets/New-Animals-Classification-1/test... found 22 images in 3 classes ✅
#                classes   top1_acc   top5_acc: 100% 1/1 [00:00<00:00, 76.74it/s]
#                    all      0.545          1
# Speed: 0.1ms preprocess, 0.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train2
# Results saved to runs/classify/train2
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# ## Executando treinamento com 50 épocas

# %%
#pip install --upgrade ultralytics==8.0.186 wandb

# %%
# %cd {HOME}

import wandb
from wandb.integration.ultralytics import add_wandb_callback as add_wandb_callbacks

# Load a model
model = YOLO("yolov8m-cls.pt")  # load a pretained model
add_wandb_callbacks(model)

# Use the model
results = model.train(data=dataset.location, epochs=50, imgsz=64)  # train the model
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8m-cls.pt to 'yolov8m-cls.pt'...
# /content
# 100%|██████████| 32.7M/32.7M [00:00<00:00, 218MB/s]
# New https://pypi.org/project/ultralytics/8.0.200 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.186 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=classify, mode=train, model=yolov8m-cls.pt, data=/content/datasets/New-Animals-Classification-1, epochs=50, patience=50, batch=16, imgsz=64, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/classify/train3
# train: /content/datasets/New-Animals-Classification-1/train... found 465 images in 4 classes: ERROR ❌️ requires 3 classes, not 4
# val: None...
# test: /content/datasets/New-Animals-Classification-1/test... found 22 images in 3 classes ✅
# Overriding model.yaml nc=1000 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   2655744  ultralytics.nn.modules.conv.Conv             [384, 768, 3, 2]
#   8                  -1  2   7084032  ultralytics.nn.modules.block.C2f             [768, 768, 2, True]
#   9                  -1  1    989443  ultralytics.nn.modules.head.Classify         [768, 3]
# YOLOv8m-cls summary: 141 layers, 15776179 parameters, 15776179 gradients
# Transferred 228/230 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/classify/train3', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/datasets/New-Animals-Classification-1/train... 475 images, 0 corrupt: 100%|██████████| 475/475 [00:00<?, ?it/s]
# albumentations: RandomResizedCrop(p=1.0, height=64, width=64, scale=(0.5, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1), HorizontalFlip(p=0.5), ColorJitter(p=0.5, brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.30000000000000004, 1.7], hue=[-0.015, 0.015]), Normalize(p=1.0, mean=(0.0, 0.0, 0.0), std=(1.0, 1.0, 1.0), max_pixel_value=255.0), ToTensorV2(always_apply=True, p=1.0, transpose_mask=False)
# val: Scanning /content/datasets/New-Animals-Classification-1/test... 22 images, 0 corrupt: 100%|██████████| 22/22 [00:00<?, ?it/s]
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 38 weight(decay=0.0), 39 weight(decay=0.0005), 39 bias(decay=0.0)
# Image sizes 64 train, 64 val
# Using 2 dataloader workers
# Logging results to runs/classify/train3
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/50     0.677G     0.2585         11         64: 100%|██████████| 30/30 [00:03<00:00,  7.95it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,  7.82it/s]
#                    all      0.591          1
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.32, 6.3ms
# Speed: 0.8ms preprocess, 6.3ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.34, elephant 0.32, 6.5ms
# Speed: 0.5ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.34, elephant 0.32, 6.2ms
# Speed: 0.5ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.34, elephant 0.32, 7.0ms
# Speed: 0.4ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.34, elephant 0.32, 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.34, elephant 0.32, 7.3ms
# Speed: 0.4ms preprocess, 7.3ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.32, 6.6ms
# Speed: 0.4ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.32, 8.2ms
# Speed: 0.5ms preprocess, 8.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.32, 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.32, 7.0ms
# Speed: 2.9ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.32, 7.3ms
# Speed: 0.5ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.34, elephant 0.32, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.32, 6.8ms
# Speed: 0.4ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.32, 7.1ms
# Speed: 0.5ms preprocess, 7.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.34, elephant 0.32, 7.1ms
# Speed: 0.7ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.34, elephant 0.32, 8.0ms
# Speed: 0.5ms preprocess, 8.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.32, 7.4ms
# Speed: 0.5ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.34, elephant 0.32, 6.2ms
# Speed: 0.4ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.34, elephant 0.32, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.32, 6.5ms
# Speed: 0.7ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.32, 7.3ms
# Speed: 0.3ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.32, 6.0ms
# Speed: 0.5ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/50     0.677G     0.1752         11         64: 100%|██████████| 30/30 [00:04<00:00,  6.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 16.45it/s]
#                    all      0.545          1
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.32, 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 8.2ms
# Speed: 0.5ms preprocess, 8.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 6.9ms
# Speed: 0.7ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 7.4ms
# Speed: 0.5ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 7.2ms
# Speed: 0.5ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.32, 12.8ms
# Speed: 0.7ms preprocess, 12.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 12.6ms
# Speed: 0.7ms preprocess, 12.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 7.2ms
# Speed: 0.5ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 8.6ms
# Speed: 0.7ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 7.2ms
# Speed: 0.7ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 14.4ms
# Speed: 0.4ms preprocess, 14.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 9.0ms
# Speed: 0.4ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 8.0ms
# Speed: 0.5ms preprocess, 8.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 6.0ms
# Speed: 0.5ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 7.1ms
# Speed: 0.5ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 6.2ms
# Speed: 0.6ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 6.0ms
# Speed: 0.9ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 5.6ms
# Speed: 0.3ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 5.6ms
# Speed: 0.3ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 7.0ms
# Speed: 0.9ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.34, hippopotamus 0.33, elephant 0.33, 5.9ms
# Speed: 1.9ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/50     0.661G     0.1061         11         64: 100%|██████████| 30/30 [00:04<00:00,  7.36it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 18.47it/s]
#                    all      0.727          1
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 16.5ms
# Speed: 0.6ms preprocess, 16.5ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 12.3ms
# Speed: 0.4ms preprocess, 12.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 9.9ms
# Speed: 0.4ms preprocess, 9.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 7.9ms
# Speed: 0.4ms preprocess, 7.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.36, rhinoceros 0.35, hippopotamus 0.28, 14.3ms
# Speed: 0.5ms preprocess, 14.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 12.5ms
# Speed: 0.5ms preprocess, 12.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.36, rhinoceros 0.35, hippopotamus 0.29, 8.5ms
# Speed: 0.5ms preprocess, 8.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 9.1ms
# Speed: 0.5ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 9.5ms
# Speed: 0.5ms preprocess, 9.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.36, rhinoceros 0.35, hippopotamus 0.28, 10.7ms
# Speed: 0.5ms preprocess, 10.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 9.1ms
# Speed: 1.3ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.36, rhinoceros 0.35, hippopotamus 0.28, 11.1ms
# Speed: 0.5ms preprocess, 11.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 12.9ms
# Speed: 0.5ms preprocess, 12.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 14.5ms
# Speed: 0.5ms preprocess, 14.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 10.5ms
# Speed: 0.5ms preprocess, 10.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.36, rhinoceros 0.35, hippopotamus 0.29, 9.0ms
# Speed: 0.5ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 11.3ms
# Speed: 0.5ms preprocess, 11.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.37, rhinoceros 0.35, hippopotamus 0.28, 13.6ms
# Speed: 0.5ms preprocess, 13.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/50     0.661G    0.06988         11         64: 100%|██████████| 30/30 [00:03<00:00,  9.85it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 20.24it/s]
#                    all      0.773          1
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.7ms
# Speed: 0.6ms preprocess, 7.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.1ms
# Speed: 0.6ms preprocess, 7.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.3ms
# Speed: 0.5ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.0ms
# Speed: 0.6ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.38, hippopotamus 0.25, 7.2ms
# Speed: 0.8ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.2ms
# Speed: 0.7ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.6ms
# Speed: 0.6ms preprocess, 7.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.3ms
# Speed: 0.5ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 11.7ms
# Speed: 0.5ms preprocess, 11.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.2ms
# Speed: 0.7ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.1ms
# Speed: 0.7ms preprocess, 7.1ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.38, hippopotamus 0.25, 7.0ms
# Speed: 0.7ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.0ms
# Speed: 0.7ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.4ms
# Speed: 0.8ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 6.7ms
# Speed: 2.0ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.8ms
# Speed: 1.2ms preprocess, 7.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 8.3ms
# Speed: 0.8ms preprocess, 8.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 5.9ms
# Speed: 0.7ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.2ms
# Speed: 0.5ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 9.6ms
# Speed: 0.5ms preprocess, 9.6ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 6.3ms
# Speed: 0.4ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 6.2ms
# Speed: 0.6ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/50     0.661G    0.05587         11         64: 100%|██████████| 30/30 [00:03<00:00,  9.73it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 19.88it/s]
#                    all      0.591          1
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 8.6ms
# Speed: 1.6ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.0ms
# Speed: 0.5ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 6.3ms
# Speed: 0.4ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 6.5ms
# Speed: 0.6ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 10.5ms
# Speed: 0.4ms preprocess, 10.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 6.5ms
# Speed: 0.4ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 6.3ms
# Speed: 0.4ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 6.3ms
# Speed: 0.6ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.3ms
# Speed: 0.5ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 11.2ms
# Speed: 0.5ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.7ms
# Speed: 0.5ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 6.1ms
# Speed: 0.7ms preprocess, 6.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.9ms
# Speed: 0.8ms preprocess, 7.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.1ms
# Speed: 0.5ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.4ms
# Speed: 0.7ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.2ms
# Speed: 0.8ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.4ms
# Speed: 0.8ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 5.7ms
# Speed: 1.0ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 7.1ms
# Speed: 0.4ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 9.0ms
# Speed: 0.5ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 5.6ms
# Speed: 1.1ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.38, elephant 0.37, hippopotamus 0.25, 5.7ms
# Speed: 0.3ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/50     0.661G    0.05755         11         64: 100%|██████████| 30/30 [00:05<00:00,  5.77it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 17.26it/s]
#                    all      0.727          1
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 8.3ms
# Speed: 0.5ms preprocess, 8.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 8.0ms
# Speed: 0.6ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.31, 6.7ms
# Speed: 0.4ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 7.2ms
# Speed: 0.5ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.31, 7.4ms
# Speed: 0.5ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 7.9ms
# Speed: 0.6ms preprocess, 7.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 8.4ms
# Speed: 1.2ms preprocess, 8.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 12.6ms
# Speed: 0.5ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 7.2ms
# Speed: 0.6ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 6.7ms
# Speed: 0.6ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.36, elephant 0.34, hippopotamus 0.30, 7.8ms
# Speed: 0.4ms preprocess, 7.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 6.4ms
# Speed: 0.5ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 6.3ms
# Speed: 0.4ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 8.1ms
# Speed: 0.9ms preprocess, 8.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.36, elephant 0.34, hippopotamus 0.30, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 9.8ms
# Speed: 0.7ms preprocess, 9.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 7.4ms
# Speed: 0.5ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 7.3ms
# Speed: 0.5ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 6.2ms
# Speed: 0.6ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 7.1ms
# Speed: 0.9ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.35, elephant 0.34, hippopotamus 0.30, 6.8ms
# Speed: 0.4ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/50     0.661G    0.08101         11         64: 100%|██████████| 30/30 [00:03<00:00,  9.94it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 25.18it/s]
#                    all      0.773          1
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 10.6ms
# Speed: 0.6ms preprocess, 10.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.23, 6.8ms
# Speed: 0.8ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.36, hippopotamus 0.23, 6.3ms
# Speed: 0.7ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.23, 7.1ms
# Speed: 0.5ms preprocess, 7.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 7.3ms
# Speed: 0.4ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 7.3ms
# Speed: 0.4ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 6.9ms
# Speed: 0.5ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 6.3ms
# Speed: 0.8ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 6.7ms
# Speed: 0.7ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 9.0ms
# Speed: 1.3ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 6.9ms
# Speed: 0.6ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 7.8ms
# Speed: 0.5ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 7.4ms
# Speed: 0.5ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 11.4ms
# Speed: 0.9ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 9.4ms
# Speed: 0.5ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 7.5ms
# Speed: 0.5ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 6.4ms
# Speed: 0.4ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.37, hippopotamus 0.22, 6.6ms
# Speed: 0.5ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.41, elephant 0.36, hippopotamus 0.22, 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/50     0.661G    0.07538         11         64: 100%|██████████| 30/30 [00:03<00:00,  9.45it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 17.95it/s]
#                    all      0.727          1
#
# 0: 64x64 elephant 0.50, rhinoceros 0.35, hippopotamus 0.15, 15.8ms
# Speed: 0.6ms preprocess, 15.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.48, rhinoceros 0.36, hippopotamus 0.16, 7.8ms
# Speed: 0.4ms preprocess, 7.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.49, rhinoceros 0.36, hippopotamus 0.15, 6.4ms
# Speed: 0.5ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.49, rhinoceros 0.35, hippopotamus 0.15, 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.48, rhinoceros 0.36, hippopotamus 0.15, 9.7ms
# Speed: 0.4ms preprocess, 9.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.49, rhinoceros 0.36, hippopotamus 0.15, 8.9ms
# Speed: 0.5ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.50, rhinoceros 0.35, hippopotamus 0.15, 14.5ms
# Speed: 3.1ms preprocess, 14.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.49, rhinoceros 0.36, hippopotamus 0.15, 13.6ms
# Speed: 5.2ms preprocess, 13.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.50, rhinoceros 0.35, hippopotamus 0.15, 16.4ms
# Speed: 0.5ms preprocess, 16.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.49, rhinoceros 0.36, hippopotamus 0.15, 13.1ms
# Speed: 0.5ms preprocess, 13.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.49, rhinoceros 0.35, hippopotamus 0.15, 9.6ms
# Speed: 0.5ms preprocess, 9.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.49, rhinoceros 0.36, hippopotamus 0.15, 7.0ms
# Speed: 0.4ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.50, rhinoceros 0.35, hippopotamus 0.15, 10.0ms
# Speed: 0.5ms preprocess, 10.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.49, rhinoceros 0.36, hippopotamus 0.15, 10.6ms
# Speed: 0.5ms preprocess, 10.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.50, rhinoceros 0.35, hippopotamus 0.15, 7.8ms
# Speed: 0.4ms preprocess, 7.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.50, rhinoceros 0.36, hippopotamus 0.15, 6.5ms
# Speed: 0.4ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.49, rhinoceros 0.36, hippopotamus 0.15, 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.49, rhinoceros 0.35, hippopotamus 0.15, 7.2ms
# Speed: 0.5ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.49, rhinoceros 0.36, hippopotamus 0.15, 7.2ms
# Speed: 0.6ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.49, rhinoceros 0.36, hippopotamus 0.15, 7.2ms
# Speed: 0.4ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.49, rhinoceros 0.36, hippopotamus 0.15, 12.7ms
# Speed: 0.5ms preprocess, 12.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.50, rhinoceros 0.35, hippopotamus 0.15, 8.1ms
# Speed: 0.5ms preprocess, 8.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/50     0.661G    0.08088         11         64: 100%|██████████| 30/30 [00:04<00:00,  6.67it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 20.62it/s]
#                    all      0.636          1
#
# 0: 64x64 elephant 0.59, hippopotamus 0.31, rhinoceros 0.10, 11.2ms
# Speed: 0.6ms preprocess, 11.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.62, hippopotamus 0.28, rhinoceros 0.09, 9.8ms
# Speed: 0.4ms preprocess, 9.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.61, hippopotamus 0.29, rhinoceros 0.09, 6.7ms
# Speed: 0.5ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.60, hippopotamus 0.30, rhinoceros 0.10, 6.7ms
# Speed: 0.4ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.61, hippopotamus 0.29, rhinoceros 0.10, 7.0ms
# Speed: 0.4ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.60, hippopotamus 0.31, rhinoceros 0.09, 6.5ms
# Speed: 0.4ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.60, hippopotamus 0.30, rhinoceros 0.10, 10.7ms
# Speed: 0.4ms preprocess, 10.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.60, hippopotamus 0.30, rhinoceros 0.10, 6.8ms
# Speed: 0.5ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.61, hippopotamus 0.30, rhinoceros 0.10, 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.62, hippopotamus 0.28, rhinoceros 0.10, 6.7ms
# Speed: 0.6ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.62, hippopotamus 0.29, rhinoceros 0.09, 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.60, hippopotamus 0.30, rhinoceros 0.10, 7.8ms
# Speed: 0.6ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.60, hippopotamus 0.30, rhinoceros 0.10, 8.3ms
# Speed: 0.5ms preprocess, 8.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.62, hippopotamus 0.28, rhinoceros 0.10, 7.4ms
# Speed: 0.5ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.61, hippopotamus 0.30, rhinoceros 0.10, 7.4ms
# Speed: 0.5ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.63, hippopotamus 0.28, rhinoceros 0.09, 7.9ms
# Speed: 0.5ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.60, hippopotamus 0.31, rhinoceros 0.10, 6.0ms
# Speed: 0.5ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.61, hippopotamus 0.30, rhinoceros 0.10, 8.2ms
# Speed: 0.6ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.62, hippopotamus 0.29, rhinoceros 0.09, 6.9ms
# Speed: 0.8ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.61, hippopotamus 0.30, rhinoceros 0.09, 7.4ms
# Speed: 0.5ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.59, hippopotamus 0.31, rhinoceros 0.10, 5.8ms
# Speed: 0.4ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.62, hippopotamus 0.28, rhinoceros 0.10, 7.0ms
# Speed: 0.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/50     0.661G    0.05509         11         64: 100%|██████████| 30/30 [00:03<00:00,  9.51it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 26.42it/s]
#                    all      0.727          1
#
# 0: 64x64 elephant 0.95, rhinoceros 0.03, hippopotamus 0.02, 6.6ms
# Speed: 0.8ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.94, rhinoceros 0.04, hippopotamus 0.02, 7.6ms
# Speed: 0.6ms preprocess, 7.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.93, rhinoceros 0.04, hippopotamus 0.03, 6.8ms
# Speed: 0.4ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.93, rhinoceros 0.04, hippopotamus 0.02, 6.5ms
# Speed: 0.4ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.93, rhinoceros 0.04, hippopotamus 0.03, 6.5ms
# Speed: 0.4ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.93, rhinoceros 0.04, hippopotamus 0.03, 6.3ms
# Speed: 0.5ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.93, rhinoceros 0.04, hippopotamus 0.03, 6.3ms
# Speed: 0.5ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.94, rhinoceros 0.04, hippopotamus 0.02, 6.5ms
# Speed: 0.4ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.94, rhinoceros 0.04, hippopotamus 0.02, 6.5ms
# Speed: 0.4ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.93, rhinoceros 0.05, hippopotamus 0.03, 8.7ms
# Speed: 0.6ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.94, rhinoceros 0.04, hippopotamus 0.02, 8.4ms
# Speed: 0.5ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.93, rhinoceros 0.04, hippopotamus 0.03, 9.0ms
# Speed: 1.1ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.93, rhinoceros 0.04, hippopotamus 0.02, 7.3ms
# Speed: 1.1ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.93, rhinoceros 0.04, hippopotamus 0.02, 5.9ms
# Speed: 2.6ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.95, rhinoceros 0.03, hippopotamus 0.02, 7.7ms
# Speed: 0.5ms preprocess, 7.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.93, rhinoceros 0.04, hippopotamus 0.03, 7.1ms
# Speed: 0.5ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.94, rhinoceros 0.04, hippopotamus 0.02, 7.4ms
# Speed: 0.7ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.93, rhinoceros 0.04, hippopotamus 0.03, 6.0ms
# Speed: 0.5ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.95, rhinoceros 0.03, hippopotamus 0.02, 7.1ms
# Speed: 0.5ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.93, rhinoceros 0.04, hippopotamus 0.02, 7.6ms
# Speed: 0.5ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.94, rhinoceros 0.04, hippopotamus 0.02, 6.1ms
# Speed: 0.5ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.93, rhinoceros 0.04, hippopotamus 0.02, 7.3ms
# Speed: 0.5ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/50     0.661G    0.03856         11         64: 100%|██████████| 30/30 [00:03<00:00,  9.95it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 19.95it/s]
#                    all      0.727          1
#
# 0: 64x64 elephant 0.96, rhinoceros 0.02, hippopotamus 0.02, 8.2ms
# Speed: 0.6ms preprocess, 8.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.96, rhinoceros 0.02, hippopotamus 0.02, 12.6ms
# Speed: 0.4ms preprocess, 12.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.96, rhinoceros 0.02, hippopotamus 0.02, 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.97, rhinoceros 0.02, hippopotamus 0.01, 11.3ms
# Speed: 0.4ms preprocess, 11.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.96, rhinoceros 0.02, hippopotamus 0.01, 15.3ms
# Speed: 0.4ms preprocess, 15.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.96, rhinoceros 0.02, hippopotamus 0.02, 7.7ms
# Speed: 0.5ms preprocess, 7.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.96, rhinoceros 0.02, hippopotamus 0.02, 11.4ms
# Speed: 0.4ms preprocess, 11.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.97, rhinoceros 0.02, hippopotamus 0.01, 16.3ms
# Speed: 0.4ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.95, rhinoceros 0.03, hippopotamus 0.02, 12.6ms
# Speed: 0.4ms preprocess, 12.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.96, rhinoceros 0.02, hippopotamus 0.02, 10.7ms
# Speed: 0.5ms preprocess, 10.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.96, rhinoceros 0.02, hippopotamus 0.02, 16.6ms
# Speed: 0.5ms preprocess, 16.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.96, rhinoceros 0.02, hippopotamus 0.01, 9.2ms
# Speed: 0.5ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.95, rhinoceros 0.03, hippopotamus 0.02, 6.6ms
# Speed: 0.5ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.96, rhinoceros 0.02, hippopotamus 0.02, 10.3ms
# Speed: 0.4ms preprocess, 10.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.97, rhinoceros 0.02, hippopotamus 0.01, 8.6ms
# Speed: 0.5ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.95, rhinoceros 0.03, hippopotamus 0.02, 8.6ms
# Speed: 0.5ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.96, rhinoceros 0.02, hippopotamus 0.02, 7.5ms
# Speed: 0.5ms preprocess, 7.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.95, rhinoceros 0.03, hippopotamus 0.02, 7.0ms
# Speed: 0.7ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.95, rhinoceros 0.03, hippopotamus 0.02, 16.2ms
# Speed: 0.4ms preprocess, 16.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.95, rhinoceros 0.03, hippopotamus 0.02, 7.0ms
# Speed: 0.5ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.96, rhinoceros 0.03, hippopotamus 0.02, 8.0ms
# Speed: 0.5ms preprocess, 8.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 elephant 0.96, rhinoceros 0.03, hippopotamus 0.02, 6.7ms
# Speed: 0.4ms preprocess, 6.7ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/50     0.661G    0.04907         11         64: 100%|██████████| 30/30 [00:04<00:00,  6.91it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 31.26it/s]
#                    all      0.682          1
#
# 0: 64x64 rhinoceros 0.59, hippopotamus 0.23, elephant 0.18, 7.5ms
# Speed: 0.6ms preprocess, 7.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.58, hippopotamus 0.23, elephant 0.18, 6.7ms
# Speed: 0.4ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.59, hippopotamus 0.23, elephant 0.18, 6.4ms
# Speed: 0.4ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.58, hippopotamus 0.23, elephant 0.19, 7.1ms
# ...
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 33.76it/s]
#                    all      0.727          1
#
# 0: 64x64 rhinoceros 0.64, hippopotamus 0.26, elephant 0.09, 14.9ms
# Speed: 0.6ms preprocess, 14.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.66, hippopotamus 0.26, elephant 0.09, 13.9ms
# Speed: 0.5ms preprocess, 13.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.66, hippopotamus 0.26, elephant 0.08, 13.4ms
# Speed: 0.6ms preprocess, 13.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.65, hippopotamus 0.26, elephant 0.09, 11.5ms
# Speed: 0.5ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.65, hippopotamus 0.26, elephant 0.09, 12.4ms
# Speed: 0.4ms preprocess, 12.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.65, hippopotamus 0.26, elephant 0.09, 17.2ms
# Speed: 0.5ms preprocess, 17.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.65, hippopotamus 0.26, elephant 0.09, 21.3ms
# Speed: 0.4ms preprocess, 21.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.66, hippopotamus 0.25, elephant 0.08, 9.5ms
# Speed: 0.4ms preprocess, 9.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.66, hippopotamus 0.26, elephant 0.09, 15.4ms
# Speed: 0.4ms preprocess, 15.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.66, hippopotamus 0.26, elephant 0.09, 14.8ms
# Speed: 0.5ms preprocess, 14.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.66, hippopotamus 0.26, elephant 0.09, 16.1ms
# Speed: 0.5ms preprocess, 16.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.65, hippopotamus 0.26, elephant 0.09, 7.6ms
# Speed: 0.5ms preprocess, 7.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.65, hippopotamus 0.26, elephant 0.09, 8.9ms
# Speed: 0.7ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.65, hippopotamus 0.26, elephant 0.09, 6.7ms
# Speed: 0.5ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.66, hippopotamus 0.26, elephant 0.09, 7.5ms
# Speed: 0.5ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.65, hippopotamus 0.26, elephant 0.09, 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.66, hippopotamus 0.26, elephant 0.09, 7.2ms
# Speed: 0.4ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.65, hippopotamus 0.26, elephant 0.09, 6.2ms
# Speed: 0.7ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.65, hippopotamus 0.26, elephant 0.09, 7.3ms
# Speed: 0.5ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.66, hippopotamus 0.26, elephant 0.09, 7.1ms
# Speed: 2.6ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.66, hippopotamus 0.26, elephant 0.09, 7.9ms
# Speed: 0.7ms preprocess, 7.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.65, hippopotamus 0.26, elephant 0.09, 6.5ms
# Speed: 0.8ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
#       Epoch    GPU_mem       loss  Instances       Size
#       49/50     0.661G   0.004267         11         64: 100%|██████████| 30/30 [00:04<00:00,  6.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 20.62it/s]
#                    all      0.773          1
#
# 0: 64x64 rhinoceros 0.62, hippopotamus 0.27, elephant 0.11, 17.5ms
# Speed: 0.6ms preprocess, 17.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.62, hippopotamus 0.27, elephant 0.11, 10.4ms
# Speed: 0.5ms preprocess, 10.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.62, hippopotamus 0.27, elephant 0.11, 17.1ms
# Speed: 0.5ms preprocess, 17.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.62, hippopotamus 0.27, elephant 0.11, 14.2ms
# Speed: 0.5ms preprocess, 14.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.62, hippopotamus 0.27, elephant 0.11, 7.3ms
# Speed: 0.5ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.62, hippopotamus 0.27, elephant 0.11, 11.2ms
# Speed: 0.5ms preprocess, 11.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.63, hippopotamus 0.27, elephant 0.10, 12.9ms
# Speed: 0.5ms preprocess, 12.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.62, hippopotamus 0.27, elephant 0.11, 13.9ms
# Speed: 0.4ms preprocess, 13.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.63, hippopotamus 0.27, elephant 0.11, 16.0ms
# Speed: 0.5ms preprocess, 16.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.63, hippopotamus 0.27, elephant 0.11, 14.0ms
# Speed: 0.4ms preprocess, 14.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.62, hippopotamus 0.27, elephant 0.11, 10.2ms
# Speed: 0.4ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.63, hippopotamus 0.27, elephant 0.11, 12.4ms
# Speed: 0.5ms preprocess, 12.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.63, hippopotamus 0.27, elephant 0.10, 14.1ms
# Speed: 0.5ms preprocess, 14.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.63, hippopotamus 0.27, elephant 0.11, 11.0ms
# Speed: 0.6ms preprocess, 11.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.62, hippopotamus 0.27, elephant 0.11, 12.3ms
# Speed: 0.5ms preprocess, 12.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.61, hippopotamus 0.28, elephant 0.11, 15.4ms
# Speed: 2.5ms preprocess, 15.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.62, hippopotamus 0.27, elephant 0.11, 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.62, hippopotamus 0.27, elephant 0.11, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.62, hippopotamus 0.27, elephant 0.11, 13.2ms
# Speed: 0.9ms preprocess, 13.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.62, hippopotamus 0.27, elephant 0.11, 10.3ms
# Speed: 0.9ms preprocess, 10.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.62, hippopotamus 0.27, elephant 0.11, 8.6ms
# Speed: 0.5ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.63, hippopotamus 0.27, elephant 0.11, 7.4ms
# Speed: 0.9ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
#       Epoch    GPU_mem       loss  Instances       Size
#       50/50     0.661G   0.003645         11         64: 100%|██████████| 30/30 [00:03<00:00,  8.24it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 15.18it/s]
#                    all      0.818          1
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 11.3ms
# Speed: 0.6ms preprocess, 11.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 6.7ms
# Speed: 0.7ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 7.2ms
# Speed: 0.7ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 6.8ms
# Speed: 0.4ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.09, 7.8ms
# Speed: 0.4ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 7.4ms
# Speed: 0.4ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.31, elephant 0.10, 9.0ms
# Speed: 0.5ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.59, hippopotamus 0.31, elephant 0.10, 7.0ms
# Speed: 0.5ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 13.8ms
# Speed: 3.4ms preprocess, 13.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 14.6ms
# Speed: 0.5ms preprocess, 14.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.59, hippopotamus 0.31, elephant 0.10, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.31, elephant 0.10, 12.6ms
# Speed: 5.5ms preprocess, 12.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.59, hippopotamus 0.30, elephant 0.10, 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 15.6ms
# Speed: 0.5ms preprocess, 15.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 15.9ms
# Speed: 0.5ms preprocess, 15.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 8.9ms
# Speed: 0.5ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 7.3ms
# Speed: 0.5ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.09, 7.3ms
# Speed: 0.8ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.58, hippopotamus 0.31, elephant 0.10, 8.1ms
# Speed: 0.5ms preprocess, 8.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 7.5ms
# Speed: 0.5ms preprocess, 7.5ms inference, 0.4ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 6.8ms
# Speed: 0.4ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 50 epochs completed in 0.090 hours.
# Optimizer stripped from runs/classify/train3/weights/last.pt, 31.7MB
# Optimizer stripped from runs/classify/train3/weights/best.pt, 31.7MB
#
# Validating runs/classify/train3/weights/best.pt...
# Ultralytics YOLOv8.0.186 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m-cls summary (fused): 103 layers, 15766499 parameters, 0 gradients
# WARNING ⚠️ Dataset 'split=val' not found, using 'split=test' instead.
# train: /content/datasets/New-Animals-Classification-1/train... found 471 images in 4 classes: ERROR ❌️ requires 3 classes, not 4
# val: None...
# test: /content/datasets/New-Animals-Classification-1/test... found 22 images in 3 classes ✅
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 34.18it/s]
#                    all      0.818          1
# Speed: 0.0ms preprocess, 0.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train3
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 9.2ms
# Speed: 0.6ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.09, 6.8ms
# Speed: 0.5ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 7.9ms
# Speed: 0.5ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 6.7ms
# Speed: 0.4ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.31, elephant 0.10, 7.5ms
# Speed: 0.5ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.58, hippopotamus 0.31, elephant 0.10, 7.2ms
# Speed: 0.4ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 6.0ms
# Speed: 0.4ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 12.1ms
# Speed: 0.4ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 10.0ms
# Speed: 0.5ms preprocess, 10.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 9.7ms
# Speed: 0.4ms preprocess, 9.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 7.1ms
# Speed: 3.4ms preprocess, 7.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 13.7ms
# Speed: 0.5ms preprocess, 13.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 12.5ms
# Speed: 0.8ms preprocess, 12.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.31, elephant 0.10, 8.2ms
# Speed: 0.4ms preprocess, 8.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.59, hippopotamus 0.31, elephant 0.10, 10.0ms
# Speed: 0.4ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 8.0ms
# Speed: 0.5ms preprocess, 8.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.09, 7.4ms
# Speed: 0.4ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.59, hippopotamus 0.30, elephant 0.10, 9.4ms
# Speed: 0.5ms preprocess, 9.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.60, hippopotamus 0.30, elephant 0.10, 8.0ms
# Speed: 0.4ms preprocess, 8.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 rhinoceros 0.59, hippopotamus 0.31, elephant 0.10, 6.3ms
# Speed: 0.5ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/train3

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>▃▅▇████▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>lr/pg1</td><td>▃▅▇████▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>lr/pg2</td><td>▃▅▇████▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>metrics/accuracy_top1</td><td>▂▁▆▇▆▇▆▃▆▅▅▃▅▇▆▇▆▇██▇▇▆▆▅▆▇▇█▇█▆▅▆▆▆▅▆▆█</td></tr><tr><td>metrics/accuracy_top5</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>model/GFLOPs</td><td>▁</td></tr><tr><td>model/parameters</td><td>▁</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>▁</td></tr><tr><td>train/loss</td><td>█▆▄▃▂▃▃▃▂▂▂▂▂▂▁▂▁▂▁▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/loss</td><td>█▆▂▃▄▂▃▅▄▄▄▄▃▂▃▃▃▂▁▁▂▂▂▂▃▂▁▁▂▂▁▁▂▂▂▃▂▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>4e-05</td></tr><tr><td>lr/pg1</td><td>4e-05</td></tr><tr><td>lr/pg2</td><td>4e-05</td></tr><tr><td>metrics/accuracy_top1</td><td>0.81818</td></tr><tr><td>metrics/accuracy_top5</td><td>1.0</td></tr><tr><td>model/GFLOPs</td><td>0.0</td></tr><tr><td>model/parameters</td><td>15776179</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>5.578</td></tr><tr><td>train/loss</td><td>0.00364</td></tr><tr><td>val/loss</td><td>0.26929</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">polar-pond-2</strong> at: <a href='https://wandb.ai/cesar-recife/cesar-scholl-animals-classification-yolov8/runs/zu4b49ux' target="_blank">https://wandb.ai/cesar-recife/cesar-scholl-animals-classification-yolov8/runs/zu4b49ux</a><br/>Synced 5 W&B file(s), 22 media file(s), 563 artifact file(s) and 0 other file(s)
# Find logs at: <code>./datasets/New-Animals-Classification-1/train/rhinoceros/wandb/run-20231019_185404-zu4b49ux/logs</code>

# %% [markdown]
# ## Plot Metrics

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt


results_path = './runs/classify/train3/results.csv'

results = pd.read_csv(results_path)

plt.figure()
plt.plot(results['                  epoch'], results['             train/loss'], label='train loss')
plt.plot(results['                  epoch'], results['               val/loss'], label='val loss', c='red')
plt.grid()
plt.title('Loss vs epochs')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend()


plt.figure()
plt.plot(results['                  epoch'], results['  metrics/accuracy_top1'] * 100)
plt.grid()
plt.title('Validation accuracy vs epochs')
plt.ylabel('accuracy (%)')
plt.xlabel('epochs')

plt.show()

# %% [markdown]
# ## Verificando resultados

# %%
# !ls -la {HOME}/runs/classify/train3/
# Out:
# total 856
# drwxr-xr-x 3 root root   4096 Oct 19 19:05 .
# drwxr-xr-x 6 root root   4096 Oct 19 18:59 ..
# -rw-r--r-- 1 root root   1433 Oct 19 18:59 args.yaml
# -rw-r--r-- 1 root root 113473 Oct 19 19:04 confusion_matrix_normalized.png
# -rw-r--r-- 1 root root 101392 Oct 19 19:04 confusion_matrix.png
# -rw-r--r-- 1 root root 285155 Oct 19 19:05 events.out.tfevents.1697741973.e8f8743b1c96.303.1
# -rw-r--r-- 1 root root   9792 Oct 19 19:04 results.csv
# -rw-r--r-- 1 root root 147010 Oct 19 19:05 results.png
# -rw-r--r-- 1 root root  23800 Oct 19 18:59 train_batch0.jpg
# -rw-r--r-- 1 root root  23358 Oct 19 19:03 train_batch1200.jpg
# -rw-r--r-- 1 root root  24001 Oct 19 19:03 train_batch1201.jpg
# -rw-r--r-- 1 root root  24223 Oct 19 19:03 train_batch1202.jpg
# -rw-r--r-- 1 root root  23666 Oct 19 18:59 train_batch1.jpg
# -rw-r--r-- 1 root root  23938 Oct 19 18:59 train_batch2.jpg
# -rw-r--r-- 1 root root  24148 Oct 19 19:04 val_batch0_labels.jpg
# -rw-r--r-- 1 root root  24230 Oct 19 19:04 val_batch0_pred.jpg
# drwxr-xr-x 2 root root   4096 Oct 19 18:59 weights

# %%
# !cat {HOME}/runs/classify/train3/results.csv | head -10
# Out:
#                   epoch,             train/loss,  metrics/accuracy_top1,  metrics/accuracy_top5,               val/loss,                 lr/pg0,                 lr/pg1,                 lr/pg2
#                       1,                0.25847,                0.59091,                      1,                0.35669,             0.00020706,             0.00020706,             0.00020706
#                       2,                0.17519,                0.54545,                      1,                 0.3252,             0.00041292,             0.00041292,             0.00041292
#                       3,                0.10609,                0.72727,                      1,                0.27563,              0.0006103,              0.0006103,              0.0006103
#                       4,                0.06988,                0.77273,                      1,                0.28076,             0.00067159,             0.00067159,             0.00067159
#                       5,                0.05587,                0.59091,                      1,                0.30859,             0.00067159,             0.00067159,             0.00067159
#                       6,                0.05755,                0.72727,                      1,                 0.3042,             0.00065745,             0.00065745,             0.00065745
#                       7,                0.08101,                0.77273,                      1,                0.27197,             0.00064331,             0.00064331,             0.00064331
#                       8,                0.07538,                0.72727,                      1,                0.28052,             0.00062918,             0.00062918,             0.00062918
#                       9,                0.08088,                0.63636,                      1,                0.31396,             0.00061504,             0.00061504,             0.00061504

# %%
# %cd {HOME}
# !yolo task=classify mode=predict model={HOME}/runs/classify/train3/weights/best.pt conf=0.25 source={dataset.location}/test/elephant
# !yolo task=classify mode=predict model={HOME}/runs/classify/train3/weights/best.pt conf=0.25 source={dataset.location}/test/hippopotamus
# !yolo task=classify mode=predict model={HOME}/runs/classify/train3/weights/best.pt conf=0.25 source={dataset.location}/test/rhinoceros
# Out:
# /content
# Ultralytics YOLOv8.0.186 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m-cls summary (fused): 103 layers, 15766499 parameters, 0 gradients
#
# image 1/8 /content/datasets/New-Animals-Classification-1/test/elephant/02_elephant_day_gallery_jpg.rf.71f74c51fcf37cdb78326e91b5fa9b3b.jpg: 64x64 elephant 0.98, rhinoceros 0.02, hippopotamus 0.00, 6.3ms
# image 2/8 /content/datasets/New-Animals-Classification-1/test/elephant/10c8g6tmh0_HI_115047_jpg.rf.1d513a3c21f171ce69306b99c12025e0.jpg: 64x64 elephant 0.98, rhinoceros 0.01, hippopotamus 0.01, 6.4ms
# image 3/8 /content/datasets/New-Animals-Classification-1/test/elephant/6dueoes78_savanna_07182012_XL_287319_jpg.rf.63228411913801ab19ee5efb033043db.jpg: 64x64 elephant 0.52, rhinoceros 0.48, hippopotamus 0.00, 5.2ms
# image 4/8 /content/datasets/New-Animals-Classification-1/test/elephant/African-elephant-Kenya_jpg.rf.3745da0c953f431f6c25bcc5f3e00857.jpg: 64x64 elephant 1.00, rhinoceros 0.00, hippopotamus 0.00, 5.1ms
# image 5/8 /content/datasets/New-Animals-Classification-1/test/elephant/Herd-elephants-background-Mount-Kilimanjaro-Tanzania_jpg.rf.254f6a15e0d339ea4b3e4b2bb821a8fe.jpg: 64x64 elephant 0.99, rhinoceros 0.01, hippopotamus 0.00, 5.1ms
# image 6/8 /content/datasets/New-Animals-Classification-1/test/elephant/NationalGeographic_1185365_jpg.rf.fcd233831cefff874d58563b4163d000.jpg: 64x64 rhinoceros 0.90, elephant 0.10, hippopotamus 0.00, 5.2ms
# image 7/8 /content/datasets/New-Animals-Classification-1/test/elephant/Original_WW142116_jpg.rf.24324449554e487d9dd5aa4e30e4628f.jpg: 64x64 elephant 1.00, rhinoceros 0.00, hippopotamus 0.00, 5.1ms
# image 8/8 /content/datasets/New-Animals-Classification-1/test/elephant/Original_WW242084_jpeg.rf.5e4e2f9fd3c74598835ba9d95449c7c3.jpg: 64x64 rhinoceros 0.89, elephant 0.11, hippopotamus 0.01, 5.3ms
# Speed: 0.5ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
# Ultralytics YOLOv8.0.186 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m-cls summary (fused): 103 layers, 15766499 parameters, 0 gradients
#
# image 1/8 /content/datasets/New-Animals-Classification-1/test/hippopotamus/Hipopotamo-1-_jpg.rf.26d8b54f5f74b55bdc27400d348ef237.jpg: 64x64 hippopotamus 0.40, elephant 0.34, rhinoceros 0.26, 6.0ms
# image 2/8 /content/datasets/New-Animals-Classification-1/test/hippopotamus/Savana_Africana_hipopotamos_por_Juan_Carvalho_jpg.rf.e4020aee544c3c79df527efe22f9b5bb.jpg: 64x64 hippopotamus 0.88, elephant 0.11, rhinoceros 0.01, 6.3ms
# image 3/8 /content/datasets/New-Animals-Classification-1/test/hippopotamus/hipopotamo-465287255_jpg.rf.4604b8fb5e53497f8c1959a671e8d127.jpg: 64x64 rhinoceros 0.55, elephant 0.44, hippopotamus 0.00, 5.2ms
# image 4/8 /content/datasets/New-Animals-Classification-1/test/hippopotamus/hipopotamo-e1681429173927_jpg.rf.a9f8e1410cc502a2b720fa21713b0e70.jpg: 64x64 hippopotamus 1.00, rhinoceros 0.00, elephant 0.00, 5.2ms
# image 5/8 /content/datasets/New-Animals-Classification-1/test/hippopotamus/hippo-278517_1280_jpg.rf.9cbc5dc2ea8782324a521c73b2b6f6b5.jpg: 64x64 rhinoceros 0.59, hippopotamus 0.36, elephant 0.04, 5.2ms
# image 6/8 /content/datasets/New-Animals-Classification-1/test/hippopotamus/istockphoto-93216623-612x612_jpg.rf.2a9284be02f084746dd2ab2cd791f4f0.jpg: 64x64 hippopotamus 0.81, rhinoceros 0.17, elephant 0.03, 5.2ms
# image 7/8 /content/datasets/New-Animals-Classification-1/test/hippopotamus/nationalgeographic2744875-copia_jpg.rf.c96c77b34f6e83f6401ff2373d8123f9.jpg: 64x64 hippopotamus 1.00, rhinoceros 0.00, elephant 0.00, 5.3ms
# image 8/8 /content/datasets/New-Animals-Classification-1/test/hippopotamus/nationalgeographic2769664-copia_jpg.rf.893f9db3735adff216774c873d37f400.jpg: 64x64 hippopotamus 1.00, elephant 0.00, rhinoceros 0.00, 5.5ms
# Speed: 0.5ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
# Ultralytics YOLOv8.0.186 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m-cls summary (fused): 103 layers, 15766499 parameters, 0 gradients
#
# image 1/6 /content/datasets/New-Animals-Classification-1/test/rhinoceros/13623175-rinoceronte-caminhando-lentamente-pelo-safari-em-alta-definicao-foto_jpg.rf.93e793ecb9200c2a556a2cfdfb60e425.jpg: 64x64 rhinoceros 1.00, elephant 0.00, hippopotamus 0.00, 6.1ms
# image 2/6 /content/datasets/New-Animals-Classification-1/test/rhinoceros/845110-rinoceronte-indiano-ou-java-face-close-up-foto_jpg.rf.d5b000b759d5214ab03bb03185e8ae31.jpg: 64x64 rhinoceros 0.86, hippopotamus 0.09, elephant 0.06, 6.4ms
# image 3/6 /content/datasets/New-Animals-Classification-1/test/rhinoceros/Rinoceronte-de-Sumatra-Dicerorhinus-sumatrensis-6-1-_jpg.rf.fc41983385fbc6bcb3ed811f73e53cc2.jpg: 64x64 rhinoceros 0.50, hippopotamus 0.48, elephant 0.02, 5.3ms
# image 4/6 /content/datasets/New-Animals-Classification-1/test/rhinoceros/nascimento-filhote-rinoceronte-branco-santuario-conexao-planeta_jpg.rf.2cdc39e75b41c0b7aaccaabab6757a9c.jpg: 64x64 rhinoceros 1.00, elephant 0.00, hippopotamus 0.00, 5.1ms
# image 5/6 /content/datasets/New-Animals-Classification-1/test/rhinoceros/rhino-234581759_jpeg.rf.1ae8bfc6737e71d762af161b6b3ce0ee.jpg: 64x64 rhinoceros 0.79, hippopotamus 0.12, elephant 0.10, 5.1ms
# image 6/6 /content/datasets/New-Animals-Classification-1/test/rhinoceros/site-1_100_jpg.rf.03402f2173e8d70baf1e9982402de987.jpg: 64x64 rhinoceros 0.77, elephant 0.22, hippopotamus 0.01, 5.4ms
# Speed: 0.5ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/classify/predict3/*.jpg'):
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
for image_path in glob.glob(f'{HOME}/runs/classify/predict4/*.jpg'):
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
for image_path in glob.glob(f'{HOME}/runs/classify/predict5/*.jpg'):
      display(Image(filename=image_path, width=600))
      print("\n")

# %% [markdown]
# # Salva resultados no Google Drive

# %%
# !scp -r /content/datasets/runs/classify '/content/gdrive/My Drive/Colab Notebooks/CESAR/rna-deep-learning/Projeto-Classificação'
# Out:
# cp: cannot stat '/content/datasets/runs/classify': No such file or directory

# %% [markdown]
# # Referências
#
# *   https://github.com/computervisioneng/image-classification-yolov8/tree/main
# *   https://wandb.ai/mukilan/wildlife-yolov8/reports/A-Gentle-Introduction-to-YOLOv8--Vmlldzo0MDU5NDA2
# *   https://docs.wandb.ai/guides/integrations/ultralytics
